# %%
import pandas as pd
import networkx as nx
import numpy as np
import stellargraph as sg
from stellargraph import StellarGraph
from stellargraph.data import EdgeSplitter
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegressionCV
import matplotlib.pyplot as plt
from math import isclose
from sklearn.decomposition import PCA
import os
import numpy as np
from stellargraph import StellarGraph, datasets
from stellargraph.data import EdgeSplitter
from collections import Counter
import multiprocessing
from IPython.display import display, HTML
from sklearn.model_selection import train_test_split
from sklearn.manifold import TSNE
# Out:
# 2023-03-15 01:58:56.295640: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F AVX512_VNNI FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-03-15 01:58:56.514091: I tensorflow/core/util/port.cc:104] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2023-03-15 01:58:56.519203: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2023-03-15 01:58:56.519255: I tensorflow/compiler/xla/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# 2023-03-15 01:58:57.664031: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory
# 2023-03-15 01:58:57.664242: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory
# 2023-03-15 01:58:57.664260: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.
# 2023-03-15 01:58:58.980576: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcuda.so.1'; dlerror: libcuda.so.1: cannot open shared object file: No such file or directory
# 2023-03-15 01:58:58.980639: W tensorflow/compiler/xla/stream_executor/cuda/cuda_driver.cc:265] failed call to cuInit: UNKNOWN ERROR (303)
# 2023-03-15 01:58:58.980685: I tensorflow/compiler/xla/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (lm-dep-74fd78c88-wp8c6): /proc/driver/nvidia/version does not exist
# 2023-03-15 01:58:58.981199: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F AVX512_VNNI FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
train_df = pd.read_csv('../../../lm-vol/PicoDomain/PICO_train.csv')

# %%
test_df = pd.read_csv('../../../lm-vol/PicoDomain/PICO_test.csv')

# %%
train_df = train_df.assign(client = train_df['client'].str.split('/').map(lambda x: x[0]))
train_df.client = train_df.client.str.upper()
train_df.service = train_df.service.str.upper()
train_df
# Out:
#              client            service     id.orig_h  \
# 0        HR-WIN7-2$       KRBTGT/G.LAB   10.99.99.30
# 1        HR-WIN7-2$       KRBTGT/G.LAB   10.99.99.30
# 2    SUPERSECRETXP$       KRBTGT/G.LAB  10.99.99.160
# 3             BDUCK       KRBTGT/G.LAB   10.99.99.30
# 4             BDUCK       KRBTGT/G.LAB   10.99.99.30
# ..              ...                ...           ...
# 256    RND-WIN10-1$  DNS/CORP-DC.G.LAB   10.99.99.29
# 257          JSNAKE       KRBTGT/G.LAB   10.99.99.29
# 258          JSNAKE       KRBTGT/G.LAB   10.99.99.29
# 259          JSNAKE       CIFS/CORP-DC   10.99.99.29
# 260          JSNAKE       KRBTGT/G.LAB   10.99.99.29
#
#                                    ts
# 0    2019-07-19 00:05:03.935567+00:00
# 1    2019-07-19 00:05:03.936682+00:00
# 2    2019-07-19 00:08:55.924635+00:00
# 3    2019-07-19 00:13:13.299460+00:00
# 4    2019-07-19 00:13:13.300481+00:00
# ..                                ...
# 256  2019-07-19 18:06:19.736786+00:00
# 257  2019-07-19 18:07:59.456464+00:00
# 258  2019-07-19 18:07:59.457692+00:00
# 259  2019-07-19 18:07:59.458937+00:00
# 260  2019-07-19 18:07:59.460425+00:00
#
# [261 rows x 4 columns]

# %%
test_df = test_df.assign(client = test_df['client'].str.split('/').map(lambda x: x[0]))
test_df.client = test_df.client.str.upper()
test_df.service = test_df.service.str.upper()
test_df
# Out:
#             client                    service    id.orig_h  \
# 0            RMOLE   LDAP/CORP-DC.G.LAB/G.LAB  10.99.99.27
# 1            RMOLE   CIFS/CORP-DC.G.LAB/G.LAB  10.99.99.27
# 2            RMOLE         LDAP/CORP-DC.G.LAB  10.99.99.27
# 3     RND-WIN10-2$               KRBTGT/G.LAB  10.99.99.27
# 4     RND-WIN10-2$               KRBTGT/G.LAB  10.99.99.27
# ..             ...                        ...          ...
# 831  ADMINISTRATOR        RPCSS/CORP-DC.G.LAB  10.99.99.27
# 832  ADMINISTRATOR               KRBTGT/G.LAB  10.99.99.27
# 833  ADMINISTRATOR         HOST/CORP-DC.G.LAB  10.99.99.27
# 834  ADMINISTRATOR  RESTRICTEDKRBHOST/CORP-DC  10.99.99.27
# 835  ADMINISTRATOR               KRBTGT/G.LAB  10.99.99.27
#
#                                    ts  malicious
# 0    2019-07-19 18:08:02.481818+00:00          0
# 1    2019-07-19 18:08:03.242606+00:00          0
# 2    2019-07-19 18:08:03.318908+00:00          0
# 3    2019-07-19 18:08:03.457718+00:00          0
# 4    2019-07-19 18:08:03.459095+00:00          0
# ..                                ...        ...
# 831  2019-07-21 15:57:53.695307+00:00          1
# 832  2019-07-21 15:57:53.704911+00:00          1
# 833  2019-07-21 15:57:53.713454+00:00          1
# 834  2019-07-21 15:57:53.715331+00:00          1
# 835  2019-07-21 15:57:53.713368+00:00          1
#
# [836 rows x 5 columns]

# %%
train_clients = list(train_df.client)
train_ips = list(train_df['id.orig_h'])
train_service = list(train_df.service)
train_nodes = set(train_clients + train_ips + train_service)
# print(len(train_nodes))
test_clients = list(test_df.client)
test_ips = list(test_df['id.orig_h'])
test_service = list(test_df.service)
test_nodes = set(test_clients + test_ips + test_service)
print(len(test_nodes))
print(test_nodes.difference(train_nodes))
print(len(test_nodes.difference(train_nodes)))
# Out:
# 47
# {'HOST/SUPERSECRETXP.G.LAB', 'RPCSS/HR-WIN7-1.G.LAB', 'RPCSS/HR-WIN7-2', 'ADMINISTRATOR', 'RESTRICTEDKRBHOST/RND-WIN10-2', 'RPCSS/RND-WIN10-1.G.LAB', 'HOST/CORP-DC.G.LAB', 'RESTRICTEDKRBHOST/CORP-DC', 'GC/CORP-DC.G.LAB/G.LAB', 'RPCSS/CORP-DC.G.LAB', 'RPCSS/HR-WIN7-2.G.LAB', 'RPCSS/RND-WIN10-2.G.LAB', 'RPCSS/RND-WIN10-2', 'RPCSS/RND-WIN10-1', 'RESTRICTEDKRBHOST/HR-WIN7-1', 'PROTECTEDSTORAGE/CORP-DC.G.LAB', 'LOCAL.ADMIN', 'RESTRICTEDKRBHOST/RND-WIN10-1'}
# 18

# %%
graph_structure = ('client', 'id.orig_h', 'service')
G = nx.Graph()
for index, row in train_df.iterrows():
    user_node = row[graph_structure[0]]
    ip_node = row[graph_structure[1]]
    service_node = row[graph_structure[2]]
    G.add_nodes_from([ip_node, service_node, user_node])
    G.add_edge(ip_node, user_node)
    G.add_edge(ip_node, service_node)
# add initial user mappings
new_nodes = [
    ('10.99.99.160', 
     ['HOST/SUPERSECRETXP.G.LAB']
     ), 
    ('10.99.99.29', 
     ['RPCSS/RND-WIN10-1', 'RESTRICTEDKRBHOST/RND-WIN10-1', 'RPCSS/RND-WIN10-1.G.LAB']
     ), 
    ('10.99.99.30', 
     ['GC/CORP-DC.G.LAB/G.LAB', 'PROTECTEDSTORAGE/CORP-DC.G.LAB', 'RPCSS/HR-WIN7-2.G.LAB', 'RPCSS/HR-WIN7-2']
     ), 
    ('10.99.99.27', 
     ['RESTRICTEDKRBHOST/RND-WIN10-2', 'RPCSS/RND-WIN10-2.G.LAB', 'RPCSS/RND-WIN10-2']
     ), 
    ('10.99.99.152', 
     ['GC/CORP-DC.G.LAB/G.LAB', 'RESTRICTEDKRBHOST/HR-WIN7-1', 'RPCSS/HR-WIN7-1.G.LAB']
     ),
    ('10.99.99.5', 
     ['PROTECTEDSTORAGE/CORP-DC.G.LAB', 'HOST/CORP-DC.G.LAB', 'RPCSS/CORP-DC.G.LAB', 'LOCAL.ADMIN', 'ADMINISTRATOR', 'RESTRICTEDKRBHOST/CORP-DC']
     )
    ]
for node_set in new_nodes:
    src = node_set[0]
    for dest in node_set[1]:
        G.add_edge(src, dest)
        
nx.draw(G)

# %%
graph = StellarGraph.from_networkx(G)
print(graph.info())
# Out:
# StellarGraph: Undirected multigraph
#  Nodes: 48, Edges: 68
#
#  Node types:
#   default: [48]
#     Features: none
#     Edge types: default-default->default
#
#  Edge types:
#     default-default->default: [68]
#         Weights: all 1 (default)
#         Features: none

# %%
p = 1.0
q = 1.0
dimensions = 128
num_walks = 20
walk_length = 10
window_size = 2
num_iter = 100
workers = 8

# %%
from stellargraph.data import BiasedRandomWalk
from gensim.models import Word2Vec
from gensim.models.callbacks import CallbackAny2Vec

# init callback class
class callback(CallbackAny2Vec):
    """
    Callback to print loss after each epoch
    """
    def __init__(self):
        self.epoch = 0

    def on_epoch_end(self, model):
        loss = model.get_latest_training_loss()
        if self.epoch == 0:
            print('Loss after epoch {}: {}'.format(self.epoch, loss))
        else:
            print('Loss after epoch {}: {}'.format(self.epoch, loss- self.loss_previous_step))
        self.epoch += 1
        self.loss_previous_step = loss

# %%
rw = BiasedRandomWalk(graph)
walks = rw.run(graph.nodes(), n=num_walks, length=walk_length, p=p, q=q)
print(f"Number of random walks for Graph: {len(walks)}")
model = Word2Vec(
    walks,
    vector_size=dimensions,
    window=window_size,
    min_count=0,
    sg=0,
    hs=0,
    negative=10,
    cbow_mean=1,
    workers=workers,
    epochs=num_iter,
    compute_loss=True,
    callbacks=[callback()]
)
model.get_latest_training_loss()
# Out:
# Number of random walks for Graph: 960
# Loss after epoch 0: 13887.1455078125
# Loss after epoch 1: 8739.5830078125
# Loss after epoch 2: 8544.23828125
# Loss after epoch 3: 8396.341796875
# Loss after epoch 4: 8410.55859375
# Loss after epoch 5: 7950.578125
# Loss after epoch 6: 7715.95703125
# Loss after epoch 7: 7611.26171875
# Loss after epoch 8: 7437.984375
# Loss after epoch 9: 7408.5390625
# Loss after epoch 10: 7241.3359375
# Loss after epoch 11: 7291.046875
# Loss after epoch 12: 7235.5078125
# Loss after epoch 13: 7087.703125
# Loss after epoch 14: 7357.2265625
# Loss after epoch 15: 7154.2734375
# Loss after epoch 16: 7262.03125
# Loss after epoch 17: 7226.375
# Loss after epoch 18: 7145.671875
# Loss after epoch 19: 7228.703125
# Loss after epoch 20: 7251.0625
# Loss after epoch 21: 7239.625
# Loss after epoch 22: 7325.28125
# Loss after epoch 23: 7035.796875
# Loss after epoch 24: 7259.59375
# Loss after epoch 25: 7289.828125
# Loss after epoch 26: 7282.03125
# Loss after epoch 27: 7134.625
# Loss after epoch 28: 7201.21875
# Loss after epoch 29: 7039.671875
# Loss after epoch 30: 7317.65625
# Loss after epoch 31: 7331.6875
# Loss after epoch 32: 7083.890625
# Loss after epoch 33: 7175.9375
# Loss after epoch 34: 7217.34375
# Loss after epoch 35: 7158.15625
# Loss after epoch 36: 7261.65625
# Loss after epoch 37: 7188.96875
# Loss after epoch 38: 7127.5625
# Loss after epoch 39: 7423.4375
# Loss after epoch 40: 7074.34375
# Loss after epoch 41: 7243.0625
# Loss after epoch 42: 7214.78125
# Loss after epoch 43: 7019.90625
# Loss after epoch 44: 7136.78125
# Loss after epoch 45: 7192.59375
# Loss after epoch 46: 7230.3125
# Loss after epoch 47: 7300.34375
# Loss after epoch 48: 7131.65625
# Loss after epoch 49: 7165.40625
# Loss after epoch 50: 7287.21875
# Loss after epoch 51: 7207.28125
# Loss after epoch 52: 7165.15625
# Loss after epoch 53: 7057.84375
# Loss after epoch 54: 7092.8125
# Loss after epoch 55: 7191.25
# Loss after epoch 56: 7267.40625
# Loss after epoch 57: 7159.15625
# Loss after epoch 58: 7082.6875
# Loss after epoch 59: 7131.6875
# Loss after epoch 60: 7133.78125
# Loss after epoch 61: 7311.5
# Loss after epoch 62: 7231.0
# Loss after epoch 63: 7157.40625
# Loss after epoch 64: 7118.0
# Loss after epoch 65: 7204.75
# Loss after epoch 66: 7226.78125
# Loss after epoch 67: 7041.9375
# Loss after epoch 68: 7002.84375
# Loss after epoch 69: 7005.65625
# Loss after epoch 70: 7168.5625
# Loss after epoch 71: 7054.5
# Loss after epoch 72: 6973.625
# Loss after epoch 73: 7004.75
# Loss after epoch 74: 6998.5625
# Loss after epoch 75: 7098.5
# Loss after epoch 76: 7093.25
# Loss after epoch 77: 7053.75
# Loss after epoch 78: 7170.5
# Loss after epoch 79: 7153.75
# Loss after epoch 80: 7093.6875
# Loss after epoch 81: 7141.25
# Loss after epoch 82: 7210.3125
# Loss after epoch 83: 7166.4375
# Loss after epoch 84: 7166.9375
# Loss after epoch 85: 6964.0
# Loss after epoch 86: 7011.5625
# Loss after epoch 87: 7172.1875
# Loss after epoch 88: 7103.25
# Loss after epoch 89: 6901.25
# Loss after epoch 90: 7014.3125
# Loss after epoch 91: 7005.0
# Loss after epoch 92: 7048.125
# Loss after epoch 93: 6987.6875
# Loss after epoch 94: 7092.6875
# Loss after epoch 95: 7090.375
# Loss after epoch 96: 6998.1875
# Loss after epoch 97: 7038.1875
# Loss after epoch 98: 6980.0
# Loss after epoch 99: 7016.625
# 729434.25

# %%
node_ids = model.wv.index_to_key  # list of node IDs
node_embeddings = (model.wv.vectors)

# %%
from sklearn.manifold import TSNE

tsne = TSNE(n_components=2, random_state=7, perplexity=15)
embeddings_2d = tsne.fit_transform(node_embeddings)
figure = plt.figure(figsize=(11, 9))

ax = figure.add_subplot(111)

ax.scatter(embeddings_2d[:, 0], embeddings_2d[:, 1])

# %%
def operator_hadamard(u, v):
    return u * v

# %%
# Define an edge splitter on the original graph:
edge_splitter_test = EdgeSplitter(G)

# Randomly sample a fraction p=0.1 of all positive links, and same number of negative links, from graph, and obtain the
# reduced graph graph_test with the sampled links removed:
graph_test, edges_train, labels_train = edge_splitter_test.train_test_split(
    p=0.99, method="global"
)
# Out:
# ** Sampled 67 positive and 67 negative edges. **

# %%
training_edges = [operator_hadamard(model.wv[edge[0]], model.wv[edge[1]]) for edge in edges_train]
print(len(training_edges))
# Out:
# 134

# %%
from sklearn.linear_model import LogisticRegressionCV
clf = LogisticRegressionCV(cv=5, max_iter=1000, random_state=0).fit(training_edges, labels_train)
clf.score(training_edges, labels_train)
# Out:
# 0.9925373134328358

# %%
test_G = nx.Graph()
for index, row in test_df.iterrows():
    user_node = row[graph_structure[0]]
    ip_node = row[graph_structure[1]]
    service_node = row[graph_structure[2]]
    test_G.add_nodes_from([ip_node, service_node, user_node])
    test_G.add_edge(user_node, ip_node)
    test_G.add_edge(ip_node, service_node)

# %%
test_nodes = set(test_G.nodes)
train_nodes = set(G.nodes)
missing_nodes = test_nodes.difference(train_nodes)
filtered_test_G = test_G.copy()
for index, edge in enumerate(filtered_test_G.edges):
    if edge[0] in missing_nodes or edge[1] in missing_nodes:
        filtered_test_G.remove_edge(*edge)

# %%
edge_vectors = []
for index, edge in enumerate(filtered_test_G.edges):
    src = model.wv[edge[0]]
    dest = model.wv[edge[1]]
    src_to_dest = [operator_hadamard(src, dest)]
    prob = clf.predict_proba(src_to_dest)
    if prob[0][1] <= 0.1:
        edge_vectors.append((src_to_dest, 1))
    else:
        edge_vectors.append((src_to_dest, 0))

# %%
anomalous_edge_vectors = filter(lambda x: x[1] == 1, edge_vectors)
print(len(list(anomalous_edge_vectors)))
# Out:
# 29

# %%
tsne = TSNE(n_components=2, random_state=7, perplexity=15)
embeddings = np.array([edge[0][0] for edge in edge_vectors])
embeddings_2d = tsne.fit_transform(embeddings)

# %%
labels = np.array([edge[1] for edge in edge_vectors])
figure = plt.figure(figsize=(11, 9))

ax = figure.add_subplot(111)

ax.scatter(embeddings_2d[:, 0], embeddings_2d[:, 1], s=5, c=labels, cmap='bwr')

# %%
predictions = []
for index, row in test_df.iterrows():
    try:
        client = model.wv[row['client']]
        ip = model.wv[row['id.orig_h']]
        service = model.wv[row['service']]
        client_to_ip = [operator_hadamard(client, ip)]
        ip_to_service = [operator_hadamard(service, ip)]
        prob1 = clf.predict_proba(client_to_ip)
        prob2 = clf.predict_proba(ip_to_service)
        if prob1[0][1] <= 0.1:
            predictions.append(1)
        elif prob2[0][1]<= 0.1:
            predictions.append(1)
        else:
            predictions.append(0)
    except:
        predictions.append(-1)
test_df['predictions'] = predictions

# %%
test_df[['client', 'service', 'id.orig_h', 'predictions', 'malicious']]
# Out:
#             client                    service    id.orig_h  predictions  \
# 0            RMOLE   LDAP/CORP-DC.G.LAB/G.LAB  10.99.99.27            0
# 1            RMOLE   CIFS/CORP-DC.G.LAB/G.LAB  10.99.99.27            0
# 2            RMOLE         LDAP/CORP-DC.G.LAB  10.99.99.27            0
# 3     RND-WIN10-2$               KRBTGT/G.LAB  10.99.99.27            0
# 4     RND-WIN10-2$               KRBTGT/G.LAB  10.99.99.27            0
# ..             ...                        ...          ...          ...
# 831  ADMINISTRATOR        RPCSS/CORP-DC.G.LAB  10.99.99.27            1
# 832  ADMINISTRATOR               KRBTGT/G.LAB  10.99.99.27            1
# 833  ADMINISTRATOR         HOST/CORP-DC.G.LAB  10.99.99.27            1
# 834  ADMINISTRATOR  RESTRICTEDKRBHOST/CORP-DC  10.99.99.27            1
# 835  ADMINISTRATOR               KRBTGT/G.LAB  10.99.99.27            1
#
#      malicious
# 0            0
# 1            0
# 2            0
# 3            0
# 4            0
# ..         ...
# 831          1
# 832          1
# 833          1
# 834          1
# 835          1
#
# [836 rows x 5 columns]

# %%
red_labels = list(test_df.malicious)
labels = list(test_df.predictions)
true_positives = 0
false_positives = 0
true_negatives = 0
false_negatives = 0
for index, label in enumerate(labels):
    if label == 1:
        if red_labels[index] == 1:
            true_positives += 1
        else:
            false_positives += 1
    else:
        if red_labels[index] == 1:
            false_negatives += 1
        else:
            true_negatives += 1
print(f'true postives: {true_positives}')
print(f'true negatives: {true_negatives}')
print(f'false postives: {false_positives}')
print(f'false negatives: {false_negatives}')
print(f'false positive rate: {false_positives/(true_negatives+false_positives)}')
print(f'true positive rate: {true_positives/(true_positives+false_negatives)}')
# Out:
# true postives: 126
# true negatives: 696
# false postives: 8
# false negatives: 6
# false positive rate: 0.011363636363636364
# true positive rate: 0.9545454545454546

# %%
test_df['predictions'].value_counts()
# Out:
# 0    702
# 1    134
# Name: predictions, dtype: int64

# %%
anomaly_df = test_df[test_df['predictions'] == 1]
missing_df = test_df[test_df['predictions'] == -1]

# %%
def explain_graph(anomaly, train_graph):
    client_neighbors = [n for n in train_graph.neighbors(anomaly[0])]
    ip_neighbors = [n for n in train_graph.neighbors(anomaly[1])]
    service_neighbors = [n for n in train_graph.neighbors(anomaly[2])]
    print(f'client {anomaly[0]} has {len(client_neighbors)} neighbors')
    print(f'ip {anomaly[1]} has {len(ip_neighbors)} neighbors')
    print(f'service {anomaly[2]} has {len(service_neighbors)} neighbors')
    try:
        client_ip_path = nx.shortest_path(train_graph, source=anomaly[0], target=anomaly[1])
        print(f'shorest path from client to ip: {client_ip_path}')
        ip_service_path = nx.shortest_path(train_graph, source=anomaly[1], target=anomaly[2])
        print(f'shorest path from ip to service: {ip_service_path}')
        client_to_service_path = client_ip_path + ip_service_path
    except:
        client_to_service_path = []
        print('---------------------no shortest path---------------------------')
    color_map = []
    for node in train_graph.nodes:
        if node == anomaly[1]:
            color_map.append('red')
        elif node in ip_service_path:
            color_map.append('yellow')
        elif node in client_ip_path:
            color_map.append('orange')
        else:
            color_map.append('green')
    nx.draw_spring(train_graph, node_color=color_map, node_size=100)

def explain_df(anomaly, train_df):
    client_activity = train_df[train_df['client'] == anomaly[0]]
    ip_activity = train_df[train_df['id.orig_h'] == anomaly[1]]
    service_activity = train_df[train_df['service'] == anomaly[2]]
    display(client_activity)
    display(ip_activity)
    display(service_activity)

# %%
anomaly_df[['client', 'id.orig_h', 'service', 'ts']]
# Out:
#             client     id.orig_h                    service  \
# 229       SQUIRREL  10.99.99.160                   KRBTGT/G
# 308           JDOE  10.99.99.152            RPCSS/HR-WIN7-2
# 310           JDOE  10.99.99.152                      BDUCK
# 364          RMOLE   10.99.99.30                   KRBTGT/G
# 365          RMOLE   10.99.99.30                   KRBTGT/G
# ..             ...           ...                        ...
# 831  ADMINISTRATOR   10.99.99.27        RPCSS/CORP-DC.G.LAB
# 832  ADMINISTRATOR   10.99.99.27               KRBTGT/G.LAB
# 833  ADMINISTRATOR   10.99.99.27         HOST/CORP-DC.G.LAB
# 834  ADMINISTRATOR   10.99.99.27  RESTRICTEDKRBHOST/CORP-DC
# 835  ADMINISTRATOR   10.99.99.27               KRBTGT/G.LAB
#
#                                    ts
# 229  2019-07-20 12:43:15.955452+00:00
# 308  2019-07-20 15:10:17.312420+00:00
# 310  2019-07-20 15:10:17.345530+00:00
# 364  2019-07-20 16:56:24.205290+00:00
# 365  2019-07-20 16:56:24.216751+00:00
# ..                                ...
# 831  2019-07-21 15:57:53.695307+00:00
# 832  2019-07-21 15:57:53.704911+00:00
# 833  2019-07-21 15:57:53.713454+00:00
# 834  2019-07-21 15:57:53.715331+00:00
# 835  2019-07-21 15:57:53.713368+00:00
#
# [134 rows x 4 columns]

# %%
anomalies = []
for index, row in anomaly_df.iterrows():
    anomaly = [row['client'], row['id.orig_h'], row['service']]
    anomalies.append(anomaly)

for anomaly in anomalies:
    explain_graph(anomaly, G)
    explain_df(anomaly, train_df)
    break
# Out:
# client SQUIRREL has 1 neighbors
# ip 10.99.99.160 has 8 neighbors
# service KRBTGT/G has 4 neighbors
# shorest path from client to ip: ['SQUIRREL', '10.99.99.160']
# shorest path from ip to service: ['10.99.99.160', 'KRBTGT/G.LAB', '10.99.99.27', 'KRBTGT/G']
#        client                   service     id.orig_h  \
# 37   SQUIRREL              KRBTGT/G.LAB  10.99.99.160
# 38   SQUIRREL              KRBTGT/G.LAB  10.99.99.160
# 39   SQUIRREL        LDAP/CORP-DC.G.LAB  10.99.99.160
# 40   SQUIRREL              KRBTGT/G.LAB  10.99.99.160
# 41   SQUIRREL  LDAP/CORP-DC.G.LAB/G.LAB  10.99.99.160
# 42   SQUIRREL        CIFS/CORP-DC.G.LAB  10.99.99.160
# 145  SQUIRREL              KRBTGT/G.LAB  10.99.99.160
# 146  SQUIRREL              KRBTGT/G.LAB  10.99.99.160
# 147  SQUIRREL        LDAP/CORP-DC.G.LAB  10.99.99.160
# 148  SQUIRREL              KRBTGT/G.LAB  10.99.99.160
# 149  SQUIRREL  LDAP/CORP-DC.G.LAB/G.LAB  10.99.99.160
# 150  SQUIRREL        CIFS/CORP-DC.G.LAB  10.99.99.160
# 156  SQUIRREL              CIFS/CORP-DC  10.99.99.160
#
#                                    ts
# 37   2019-07-19 02:24:23.256402+00:00
# 38   2019-07-19 02:24:23.257433+00:00
# 39   2019-07-19 02:24:23.259137+00:00
# 40   2019-07-19 02:24:23.260453+00:00
# 41   2019-07-19 02:24:23.372118+00:00
# 42   2019-07-19 02:24:23.385991+00:00
# 145  2019-07-19 12:31:24.903187+00:00
# 146  2019-07-19 12:31:24.904251+00:00
# 147  2019-07-19 12:31:24.906135+00:00
# 148  2019-07-19 12:31:24.907560+00:00
# 149  2019-07-19 12:31:25.019558+00:00
# 150  2019-07-19 12:31:25.033323+00:00
# 156  2019-07-19 14:51:20.720416+00:00
#              client                   service     id.orig_h  \
# 2    SUPERSECRETXP$              KRBTGT/G.LAB  10.99.99.160
# 7    SUPERSECRETXP$              KRBTGT/G.LAB  10.99.99.160
# 11   SUPERSECRETXP$        CIFS/CORP-DC.G.LAB  10.99.99.160
# 12   SUPERSECRETXP$              KRBTGT/G.LAB  10.99.99.160
# 28   SUPERSECRETXP$        LDAP/CORP-DC.G.LAB  10.99.99.160
# 29   SUPERSECRETXP$            SUPERSECRETXP$  10.99.99.160
# 30   SUPERSECRETXP$  LDAP/CORP-DC.G.LAB/G.LAB  10.99.99.160
# 37         SQUIRREL              KRBTGT/G.LAB  10.99.99.160
# 38         SQUIRREL              KRBTGT/G.LAB  10.99.99.160
# 39         SQUIRREL        LDAP/CORP-DC.G.LAB  10.99.99.160
# 40         SQUIRREL              KRBTGT/G.LAB  10.99.99.160
# 41         SQUIRREL  LDAP/CORP-DC.G.LAB/G.LAB  10.99.99.160
# 42         SQUIRREL        CIFS/CORP-DC.G.LAB  10.99.99.160
# 77   SUPERSECRETXP$              KRBTGT/G.LAB  10.99.99.160
# 78   SUPERSECRETXP$              KRBTGT/G.LAB  10.99.99.160
# 81   SUPERSECRETXP$              KRBTGT/G.LAB  10.99.99.160
# 86   SUPERSECRETXP$              KRBTGT/G.LAB  10.99.99.160
# 94   SUPERSECRETXP$              KRBTGT/G.LAB  10.99.99.160
# 100  SUPERSECRETXP$              KRBTGT/G.LAB  10.99.99.160
# 103  SUPERSECRETXP$        CIFS/CORP-DC.G.LAB  10.99.99.160
# 104  SUPERSECRETXP$              KRBTGT/G.LAB  10.99.99.160
# 111  SUPERSECRETXP$        LDAP/CORP-DC.G.LAB  10.99.99.160
# 112  SUPERSECRETXP$            SUPERSECRETXP$  10.99.99.160
# 113  SUPERSECRETXP$  LDAP/CORP-DC.G.LAB/G.LAB  10.99.99.160
# 145        SQUIRREL              KRBTGT/G.LAB  10.99.99.160
# 146        SQUIRREL              KRBTGT/G.LAB  10.99.99.160
# 147        SQUIRREL        LDAP/CORP-DC.G.LAB  10.99.99.160
# 148        SQUIRREL              KRBTGT/G.LAB  10.99.99.160
# 149        SQUIRREL  LDAP/CORP-DC.G.LAB/G.LAB  10.99.99.160
# 150        SQUIRREL        CIFS/CORP-DC.G.LAB  10.99.99.160
# 156        SQUIRREL              CIFS/CORP-DC  10.99.99.160
# 160  SUPERSECRETXP$              CIFS/CORP-DC  10.99.99.160
# 221  SUPERSECRETXP$              KRBTGT/G.LAB  10.99.99.160
# 222  SUPERSECRETXP$              KRBTGT/G.LAB  10.99.99.160
# 227  SUPERSECRETXP$              KRBTGT/G.LAB  10.99.99.160
#
#                                    ts
# 2    2019-07-19 00:08:55.924635+00:00
# 7    2019-07-19 00:23:56.029918+00:00
# 11   2019-07-19 00:38:56.035446+00:00
# 12   2019-07-19 00:38:56.037199+00:00
# 28   2019-07-19 01:14:26.885659+00:00
# 29   2019-07-19 01:14:26.896136+00:00
# 30   2019-07-19 01:14:26.904543+00:00
# 37   2019-07-19 02:24:23.256402+00:00
# 38   2019-07-19 02:24:23.257433+00:00
# 39   2019-07-19 02:24:23.259137+00:00
# 40   2019-07-19 02:24:23.260453+00:00
# 41   2019-07-19 02:24:23.372118+00:00
# 42   2019-07-19 02:24:23.385991+00:00
# 77   2019-07-19 08:38:56.169682+00:00
# 78   2019-07-19 08:38:56.171128+00:00
# 81   2019-07-19 08:53:56.171390+00:00
# 86   2019-07-19 09:08:56.170335+00:00
# 94   2019-07-19 09:19:24.432519+00:00
# 100  2019-07-19 09:23:56.168783+00:00
# 103  2019-07-19 09:38:56.171771+00:00
# 104  2019-07-19 09:38:56.173557+00:00
# 111  2019-07-19 09:54:36.617420+00:00
# 112  2019-07-19 09:54:36.627456+00:00
# 113  2019-07-19 09:54:36.634543+00:00
# 145  2019-07-19 12:31:24.903187+00:00
# 146  2019-07-19 12:31:24.904251+00:00
# 147  2019-07-19 12:31:24.906135+00:00
# 148  2019-07-19 12:31:24.907560+00:00
# 149  2019-07-19 12:31:25.019558+00:00
# 150  2019-07-19 12:31:25.033323+00:00
# 156  2019-07-19 14:51:20.720416+00:00
# 160  2019-07-19 14:51:22.456474+00:00
# 221  2019-07-19 17:38:56.285136+00:00
# 222  2019-07-19 17:38:56.286413+00:00
# 227  2019-07-19 17:53:56.286342+00:00
#      client   service     id.orig_h                                ts
# 162   RMOLE  KRBTGT/G   10.99.99.27  2019-07-19 14:55:59.963155+00:00
# 170  JSNAKE  KRBTGT/G   10.99.99.29  2019-07-19 14:56:18.790131+00:00
# 177    JDOE  KRBTGT/G  10.99.99.152  2019-07-19 14:56:38.211018+00:00
# 178    JDOE  KRBTGT/G  10.99.99.152  2019-07-19 14:56:38.220355+00:00
# 179    JDOE  KRBTGT/G  10.99.99.152  2019-07-19 14:56:42.048994+00:00
# 186   BDUCK  KRBTGT/G   10.99.99.30  2019-07-19 14:56:48.610940+00:00
# 197    JDOE  KRBTGT/G  10.99.99.152  2019-07-19 15:34:49.415894+00:00
# 198    JDOE  KRBTGT/G  10.99.99.152  2019-07-19 15:34:49.425462+00:00
# 199    JDOE  KRBTGT/G  10.99.99.152  2019-07-19 15:34:52.693699+00:00
# 204    JDOE  KRBTGT/G  10.99.99.152  2019-07-19 15:48:02.401460+00:00
# 207   BDUCK  KRBTGT/G   10.99.99.30  2019-07-19 15:48:11.409716+00:00
# 208   BDUCK  KRBTGT/G   10.99.99.30  2019-07-19 15:48:11.419231+00:00
# 209   BDUCK  KRBTGT/G   10.99.99.30  2019-07-19 15:48:16.119847+00:00
# 228    JDOE  KRBTGT/G  10.99.99.152  2019-07-19 18:01:08.786500+00:00
# 231    JDOE  KRBTGT/G  10.99.99.152  2019-07-19 18:01:08.800201+00:00
# 232   BDUCK  KRBTGT/G   10.99.99.30  2019-07-19 18:01:15.040998+00:00
# 233   BDUCK  KRBTGT/G   10.99.99.30  2019-07-19 18:01:15.050516+00:00
# 234   BDUCK  KRBTGT/G   10.99.99.30  2019-07-19 18:01:20.003444+00:00
# 235   BDUCK  KRBTGT/G   10.99.99.30  2019-07-19 18:01:20.012685+00:00
# 236   BDUCK  KRBTGT/G   10.99.99.30  2019-07-19 18:01:22.873099+00:00
# 239  JSNAKE  KRBTGT/G   10.99.99.29  2019-07-19 18:01:44.179687+00:00
# 242   RMOLE  KRBTGT/G   10.99.99.27  2019-07-19 18:01:49.801281+00:00

# %%
def explain_graph(anomaly, train_graph):
    
    def filter_node(node):
        return node in filtered_nodes
    
    client_node, ip_node, service_node = anomaly
    client_neighbors = [n for n in train_graph.neighbors(client_node)]
    ip_neighbors = [n for n in train_graph.neighbors(ip_node)]
    service_neighbors = [n for n in train_graph.neighbors(service_node)]
    print(f'client {anomaly[0]} has {len(client_neighbors)} neighbors')
    print(f'ip {anomaly[1]} has {len(ip_neighbors)} neighbors')
    print(f'service {anomaly[2]} has {len(service_neighbors)} neighbors')
    filtered_nodes = set(client_neighbors + ip_neighbors + service_neighbors + anomaly)
    view = nx.subgraph_view(train_graph, filter_node = filter_node)
    ColorScale = plt.get_cmap('RdYlGn')
    subgraph = nx.Graph(view)
    subgraph.add_edge(client_node, ip_node)
    subgraph.add_edge(ip_node, service_node)
    for edge in subgraph.edges:
        src, dest = edge
        edge_embedding = [operator_hadamard(model.wv[src],model.wv[dest])]
        edge_prob = clf.predict_proba(edge_embedding)
        subgraph[src][dest]['prob'] = ColorScale(edge_prob[0][1])
    for node in subgraph.nodes:
        if node == client_node:
            color_map.append('yellow')
        elif node == ip_node:
            color_map.append('orange')
        elif node == service_node:
            color_map.append('red')
        else:
            color_map.append('#1f77b4')
    edge_colors = [x[2] for x in subgraph.edges.data('prob')]
    nx.draw_spring(subgraph, edge_color=edge_colors, with_labels=True)


#     print(f'client {anomaly[0]} has {len(client_neighbors)} neighbors')
#     print(f'ip {anomaly[1]} has {len(ip_neighbors)} neighbors')
#     print(f'service {anomaly[2]} has {len(service_neighbors)} neighbors')
#     try:
#         client_ip_path = nx.shortest_path(train_graph, source=anomaly[0], target=anomaly[1])
#         print(f'shorest path from client to ip: {client_ip_path}')
#         ip_service_path = nx.shortest_path(train_graph, source=anomaly[1], target=anomaly[2])
#         print(f'shorest path from ip to service: {ip_service_path}')
#         client_to_service_path = client_ip_path + ip_service_path
#     except:
#         client_to_service_path = []
#         print('---------------------no shortest path---------------------------')
#     color_map = []
#     for node in train_graph.nodes:
#         if node == anomaly[1]:
#             color_map.append('red')
#         elif node in ip_service_path:
#             color_map.append('yellow')
#         elif node in client_ip_path:
#             color_map.append('orange')
#         else:
#             color_map.append('green')
#     nx.draw_spring(train_graph, node_color=color_map, node_size=100)

# %%
explain_graph(anomalies[2], G)
# Out:
# client JDOE has 1 neighbors
# ip 10.99.99.152 has 12 neighbors
# service BDUCK has 1 neighbors
